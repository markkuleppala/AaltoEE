# %%
import matplotlib.pyplot
from pulp import *

#Sijoituskohteet
sijoituskohteiden_nimet = ["NoDur" , "Durbl" , "Manuf" , "Enrgy" , "Chems" , "BusEq" , "Telcm" , "Utils" , "Shops" , "Hlth" , "Money" , "Other"]

#Sijoituskohteiden historialliset kuukausituotot 01/2016-09/2021 
historialliset_tuotot = [[-2.1 , -12.36 , -8.64 , -12.69 , -10.84 , -8.59 , -6.26 , 4.23 , -7.24 , -18.66 , -7.12 , -9 ],
[ 1.75 , 4.81 , 3.73 , -10.99 , 3.06 , 0.66 , 1.81 , 0.61 , 3.59 , -2.92 , -0.95 , 1.89 ],
[ 4.32 , 7.3 , 9.92 , 24.15 , 11.55 , 6.71 , 4.29 , 7.79 , 7.72 , 7.69 , 5.25 , 10.94 ],
[ 1.87 , 0.98 , 4.74 , 20.48 , 7.29 , 1.1 , 2.74 , 2.52 , -0.14 , 5.16 , 3.95 , 2.62 ],
[ -1.04 , -1.07 , -0.84 , -6.5 , -1.44 , 3.73 , -0.08 , 1.99 , -3.4 , 1.38 , 1.79 , -0.48 ],
[ 3.73 , -2.93 , 0.17 , 1.13 , 0.4 , 1.47 , 1.88 , 7.2 , 0.63 , -4.53 , -2.63 , 1.23 ],
[ 8.52 , 8.9 , 7.31 , -1.09 , 6.93 , 7.3 , 2.12 , -0.75 , 4.47 , 6.25 , 4.31 , 6.67 ],
[ 1.33 , 5.59 , 1.22 , 7.78 , 6.08 , 2.82 , -0.28 , -3.99 , 0.3 , 0.88 , 4.23 , -0.09 ],
[ -2.28 , 5.83 , 0.82 , 5.07 , -0.22 , 1.95 , 0.85 , 1.32 , -1.89 , 8.03 , 0.58 , 1.33 ],
[ -4.28 , -4.23 , -4.91 , -8.18 , -1.87 , -5.1 , -4.62 , 0 , -4.22 , -13.69 , -0.95 , -5 ],
[ 3.35 , 10.18 , 12.33 , 18.37 , 8.49 , 5.11 , 5.46 , 1.29 , 9.21 , 5.29 , 12.75 , 11.84 ],
[ 0.89 , 2.27 , 1.28 , 2.16 , -1.51 , 0.15 , 4.2 , 3.96 , 2.08 , -2.7 , 6.62 , 3.15 ],
[ -0.56 , -3.01 , 3.28 , 0.68 , 1.2 , 3.35 , 2.7 , 0.11 , -2.85 , 4.74 , -0.44 , 2.9 ],
[ 1.55 , -0.28 , 0.28 , -6.96 , 2.03 , 2.2 , 0.07 , 2.98 , -1.12 , 6.26 , 2.39 , -0.39 ],
[ 1.18 , 1.29 , -0.03 , -4.96 , 2.45 , 1.86 , 0.07 , 1.4 , 0.27 , 2.29 , -1.35 , 0.51 ],
[ 0.09 , 3.65 , 1.06 , -7.12 , 0.7 , 1.62 , 6.54 , 1 , 1.67 , -3.09 , 0.47 , 0.76 ],
[ -0.85 , 0.32 , -1.32 , -7.42 , -4.11 , 2.01 , -3.66 , 1.11 , -4.02 , -5.03 , -2.74 , -2.44 ],
[ 1.44 , 3.76 , 1.67 , -0.6 , 0.97 , 1.21 , 0.16 , -1.18 , 0.01 , 10.4 , 5.02 , 3.64 ],
[ -0.85 , -1.15 , 0.34 , 1.17 , -0.74 , 1.35 , 3.07 , 3.07 , -2.53 , -2.72 , 0.39 , -0.21 ],
[ -2.18 , -4.33 , -2.58 , -8.48 , -5.36 , -1.03 , 0.41 , 0.87 , -4.44 , 1.38 , -2.55 , -1.32 ],
[ -2.85 , -5.64 , -2.2 , -12.28 , -3.27 , -2.69 , -3.35 , 1.42 , -3.28 , -8.68 , -0.89 , -3.65 ],
[ -0.25 , -4.18 , 0.33 , 0.63 , 0.24 , 1.31 , 4.39 , 1.95 , 0.45 , 4.64 , 3.16 , 2.64 ],
[ -4.89 , -3.9 , -4.61 , 21.51 , -2.69 , -4.89 , -1.19 , -5.06 , -4.97 , -5.37 , -0.39 , -3.11 ]]



#Indeksit
realisaatioiden_indeksit = range(len(historialliset_tuotot))
kohteiden_indeksit = range(len(sijoituskohteiden_nimet))
print("Sijoitus_kohteiden lukumäärä %s; Tuottorealisaatioiden lukumäätä %d." % (len(kohteiden_indeksit), len(realisaatioiden_indeksit)))

#Parametrit
vaadittu_tuotto = 1
a = 0.083 #Käytetään CVaR(1-a)% riskimittaa (1/12 = 0.083)

#Lasketaan kunkin sijoituskohteen odotettu tuotto
odotetut_tuotot={}
for j in kohteiden_indeksit:
    odotetut_tuotot[j]=sum([historialliset_tuotot[i][j] for i in realisaatioiden_indeksit])/len(realisaatioiden_indeksit)
    

#Luodaan (minimoiva) lineaarinen optimointi malli PuLP:ssa
malli = LpProblem("Portfoliomalli", LpMaximize)

#Luodaan päätösmuuttujat sijoituksille
sijoitukset={}
for j in kohteiden_indeksit:
    sijoitukset[j] = LpVariable("Sijoitus_kohteeseen_"+sijoituskohteiden_nimet[j], lowBound=0)

#Rajoitus: Sijoitusosuudet yhteensä 100%
malli +=(lpSum([sijoitukset[j] for j in kohteiden_indeksit])==1,"Sijoitusosuudet_yhteensä_100%")

#Rajoitus: Odetettu tuotto vähintää vaaditun tuoton kokoinen
malli +=(lpSum([sijoitukset[j]*odotetut_tuotot[j] for j in kohteiden_indeksit])>=vaadittu_tuotto,"Odotettutuotto")

#Muut rajoitukset:
#
# Lisää tähän
#
#



#Luodaan CVaR:n laskentaan tarvittavat apupäätösmuuttujat ja rajoitukset
t = LpVariable("t")
z={}
for i in realisaatioiden_indeksit:
    z[i] = LpVariable("z_%s"%(i+1), lowBound=0)
    malli +=(t-z[i] <= lpSum([sijoitukset[j]*historialliset_tuotot[i][j] for j in kohteiden_indeksit]),"CVar-rajoitus realisaatiolla_%s"%(i+1))

#Kohdefunktio (CVaR)
malli +=(t-lpSum([z[i] for i in realisaatioiden_indeksit])/(a*len(realisaatioiden_indeksit)),"CVaR")

#Ratkaistaan malli
malli.solve()

#Tulostetaan optimaaliset sijoitusosuudet
for i in kohteiden_indeksit:
    print("Sijoitetaan kohteeseen "+sijoituskohteiden_nimet[i]+" "+ str(sijoitukset[i].varValue*100)+"%% käytössä olevista varoista")

#Luetaan optimiportfolion tuotot eri realisaatioissa
tuotto=[]
for i in realisaatioiden_indeksit:
    tuotto.append(sum([historialliset_tuotot[i][j]*sijoitukset[j].varValue for j in kohteiden_indeksit]))

#Piirretään tuottojakauma
matplotlib.pyplot.figure(1)
matplotlib.pyplot.hist(tuotto, color = 'red', edgecolor = 'black', bins = 20) 
matplotlib.pyplot.xlabel('Tuotto %')
matplotlib.pyplot.ylabel('Frekvenssi')

#Lasketaan odotettu tuotto
odotettu_tuotto = sum(tuotto)/len(realisaatioiden_indeksit)

#Tulostetaan odotettu tuotta ja tuoton CVaR
matplotlib.pyplot.title("Optimaalisen sijoituksen tuottojakauma (odotettu tuotto="+str(odotettu_tuotto)+", CVaR="+str(value(malli.objective))+")")
